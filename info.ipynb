# %% [markdown]
# ### THE MODEL WHICH WILL TAKE OUT THE IMPORTANT INFORMATION LIKE ANY PERSONS NAME OR LOCATION OR ANY TIME GIVEN IN THE INPUT
# Give the most important information gained from the news article like, location, time, and persons name if any or multiple persons name.
# # Popularly known as NER model.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Bidirectional, TimeDistributed, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle

# %%
df = pd.read_csv("ner_dataset.tsv", sep="\t", header=None, names=["text", "label"], keep_default_na=False)
df
# Out:
#              text     label
# 0           Amber  B-PERSON
# 1          Walker  B-PERSON
# 2       confirmed         O
# 3               a         O
# 4      suspicious         O
# ...           ...       ...
# 13343       using         O
# 13344    chemical         O
# 13345         gas         O
# 13346          at         O
# 13347      07:45.    B-TIME
#
# [13348 rows x 2 columns]

# %%
import string
sentences = []
labels = []
sentence = []
label_seq = []
punctuations = [".", "!", "?"]

for i, row in df.iterrows():
    token = row["text"]
    tag = row["label"]

    sentence.append(token)
    label_seq.append(tag)

    if any(p in token for p in punctuations):
        sentences.append(sentence)
        labels.append(label_seq)
        sentence = []
        label_seq = []
print(df.head(20))  # See how tokens look
print([t for t in df["text"].unique() if "." in t])  # See tokens containing .
print([t for t in df["label"]])  # See tokens containing .
# Out:
#                text       label
# 0             Amber    B-PERSON
# 1            Walker    B-PERSON
# 2         confirmed           O
# 3                 a           O
# 4        suspicious           O
# 5           package           O
# 6               was           O
# 7             found           O
# 8              near           O
# 9   Christopherside  B-LOCATION
# 10           around           O
# 11           07:45.      B-TIME
# 12        midnight:      B-TIME
# 13     Surveillance           O
# 14         detected           O
# 15           Joseph    B-PERSON
# 16          Elliott    B-PERSON
# 17     transporting           O
# 18              IED    B-WEAPON
# 19          through           O
# ['07:45.', 'Kimmouth.', 'IED.', 'evening.', 'grenade.', 'drone.', '20:15.', 'Eric.', '03:00.', 'AK-47.', '13:30.', 'Dr.', 'midnight.', 'Angela.', 'Mrs.', 'Amyton.', 'Robert.', 'RPG.', 'Washingtonbury.', 'rifle.', 'Nancyhaven.', 'Thomas.', 'Lydiamouth.', 'Danieltown.', 'Ericburgh.', 'Stephanieland.', 'Benjamin.', 'Greenetown.', 'Suzanne.', 'dawn.', 'Johnstonville.', 'Angelaberg.', 'Smithstad.', 'Davenportstad.', 'Jacobshire.', 'Nicholastown.', 'Raymondbury.', 'Collinsmouth.', 'Lindaside.', 'Toddmouth.', 'Jeffreyview.', 'Whitefurt.', 'Derekland.', 'Hodgehaven.', 'Anna.', 'Sonyaborough.', 'Brandonbury.', 'Tannerstad.', 'Kerrshire.', 'gas.', 'Brandyland.', 'Savannahfurt.', 'Timothy.', 'Rodneyshire.', 'Joseview.', 'Coryville.', 'Levinehaven.', 'Madison.', 'Franklinmouth.', 'Jacobfort.', 'Abigailtown.', 'Julia.', 'Jasonton.', 'Cannonton.', 'Kelly.', 'Meyersstad.', 'Andreafort.', 'Jennifer.', 'Kenneth.', 'Deniseton.', 'Hughesport.', 'Loveton.', 'Miguel.', 'Scottton.', 'Williamburgh.', 'Christineport.', 'Kimberlyberg.', 'Sandy.', 'Harrisfurt.', 'Shane.', 'April.', 'Mr.', 'Jr.', 'Macdonaldberg.', 'Christina.', 'Kimberly.', 'Jason.', 'Richardbury.', 'Heather.', 'Nguyenfort.', 'Melissaport.', 'Daniel.', 'Trevinomouth.', 'Butlerland.', 'Warrenview.', 'Travisview.', 'Matthew.', 'Kelsey.', 'Olsonshire.', 'Susanstad.', 'Keith.', 'Campbellchester.', 'Ms.', 'Kimberlyside.', 'Jillbury.', 'Monicaland.', 'Jacksonmouth.', 'Crystalchester.', 'Woodmouth.', 'Jeremyborough.', 'Cherylstad.', 'Johnstad.', 'Alexandertown.', 'Millershire.', 'Deborahmouth.', 'Brian.', 'Alexandra.', 'Woodshire.', 'Perry.', 'Reginaport.', 'Harveystad.', 'Brittany.', 'Amanda.', 'Jeremytown.', 'Richard.', 'Stephentown.', 'Dawnhaven.', 'Rogersport.', 'Garyside.', 'Perezbury.', 'Rodriguezhaven.', 'Miranda.', 'Pamelaton.', 'Cruzberg.', 'Nathaniel.', 'Veronica.', 'Anthony.', 'Roberthaven.', 'Mercadoview.', 'Danielbury.', 'Laurenborough.', 'Lindsaystad.', 'Jamesburgh.', 'Joanview.', 'Samanthatown.', 'Mitchellchester.', 'Patelborough.', 'Deborahburgh.', 'Stanleyport.', 'Bethany.', 'Gomezberg.', 'Ryan.', 'Davidhaven.', 'Jacobhaven.', 'Jamie.', 'Michael.', 'Monicaview.', 'Alyssabury.', 'Drewberg.', 'Jasminemouth.', 'Benjaminland.', 'Angelamouth.', 'Connie.', 'Alexander.', 'Monicafurt.', 'Lauren.', 'Merrittfort.', 'Melissaville.', 'Goodwinbury.', 'Hernandezport.', 'Lance.', 'Owensburgh.', 'Hayden.', 'Nicoleville.', 'Ryanberg.', 'Torresmouth.', 'Leeburgh.', 'Jordan.', 'Rothview.', 'Davidmouth.', 'Jamesville.', 'Fosterport.', 'Herreraview.', 'Hartmouth.', 'John.', 'Williamschester.', 'Garrisonland.', 'Kurtmouth.', 'Erica.', 'Diazview.', 'Laurenside.', 'Sarahborough.', 'Alexandrashire.', 'Christopherbury.', 'Christopherhaven.', 'Larsenville.', 'Grayhaven.', 'Moorebury.', 'Morganberg.', 'Chandlermouth.', 'Andersonton.', 'Claudia.', 'Cheyennemouth.', 'Meganburgh.', 'Alexandermouth.', 'Adam.', 'Christopherborough.', 'Monicamouth.', 'Baxterville.', 'Jacobton.', 'Danielmouth.', 'Jonathanberg.', 'Melissaland.', 'Charlesfort.', 'Caldwellton.', 'Larryville.']
# ['B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'B-TIME', 'B-TIME', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-WEAPON', 'O', 'B-LOCATION', 'O', 'B-TIME', 'B-PERSON', 'B-PERSON', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'B-WEAPON', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TIME', 'O', 'B-TIME', 'B-PERSON', 'B-PERSON', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-LOCATION', 'O', 'O', 'B-WEAPON', 'O', 'B-TIME', 'B-PERSON', 'B-PERSON', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'B-WEAPON', 'O', 'O', 'O', 'B-WEAPON', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TIME', 'B-TIME', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-WEAPON', 'O', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'B-WEAPON', 'O', 'B-LOCATION', 'O', 'B-TIME', 'O', 'B-TIME', 'B-PERSON', 'B-PERSON', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-LOCATION', 'O', 'O', 'B-WEAPON', 'O', 'O', 'B-LOCATION', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'B-WEAPON', 'O', 'B-TIME', 'B-PERSON', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'B-TIME', 'B-TIME', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-WEAPON', 'O', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-WEAPON', 'O', 'B-TIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-WEAPON', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-TIME', 'B-PERSON', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-WEAPON', 'O', 'B-LOCATION', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-TIME', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'B-TIME', 'B-TIME', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-WEAPON', 'O', 'B-LOCATION', 'B-TIME', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-WEAPON', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'B-TIME', 'O', 'B-TIME', 'B-PERSON', 'B-PERSON', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'B-WEAPON', 'B-PERSON', 'O', 'B-PERSON', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'B-WEAPON', 'O', 'B-LOCATION', 'O', 'B-TIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'B-TIME', 'O', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-WEAPON', 'O', 'B-TIME', 'B-TIME', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-WEAPON', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'B-WEAPON', 'O', 'B-TIME', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TIME', 'O', 'B-TIME', 'B-PERSON', 'B-PERSON', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'B-TIME', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-WEAPON', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TIME', 'B-TIME', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-WEAPON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'B-WEAPON', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TIME', 'O', 'B-WEAPON', 'O', 'B-WEAPON', 'O', 'O', 'B-LOCATION', 'O', 'O', 'B-TIME', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TIME', 'O', 'O', 'O', 'B-WEAPON', 'O', 'O', 'B-LOCATION', 'O', 'O', 'B-TIME', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'B-WEAPON', 'O', 'O', 'B-LOCATION', 'B-TIME', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-WEAPON', 'O', 'B-LOCATION', 'B-TIME', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TIME', 'O', 'B-TIME', 'B-PERSON', 'B-PERSON', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'B-LOCATION', 'O', 'O', 'B-WEAPON', 'O', 'O', 'B-LOCATION', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'B-WEAPON', 'O', 'B-TIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'B-TIM ...

# %%
words = list(set([w for s in sentences for w in s]))
tags = list(set([t for ts in labels for t in ts]))

word2idx = {w: i + 2 for i, w in enumerate(words)}
word2idx["PAD"] = 0
word2idx["OOV"] = 1

tag2idx = {t: i for i, t in enumerate(tags)}

# %%
X = [[word2idx.get(w, word2idx["OOV"]) for w in s] for s in sentences]
y = [[tag2idx[t] for t in ts] for ts in labels]

MAX_LEN = max(len(s) for s in sentences)
X = pad_sequences(X, maxlen=MAX_LEN, padding="post")
y = pad_sequences(y, maxlen=MAX_LEN, padding="post")

y = np.expand_dims(y, -1)  # Needed for sparse_categorical_crossentropy

# %%
input_word = Input(shape=(None,))
model = Embedding(input_dim=len(word2idx)+2, output_dim=64)(input_word)
model = Bidirectional(LSTM(units=64, return_sequences=True))(model)
out = TimeDistributed(Dense(len(tag2idx), activation="softmax"))(model)

model = Model(input_word, out)
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, None)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Embedding)           │ (None, None, 64)       │       112,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, None, 128)      │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, None, 5)        │           645 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 179,013 (699.27 KB)
#  Trainable params: 179,013 (699.27 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X, y, batch_size=32, epochs=5, verbose=1)
# Out:
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7492 - loss: 1.0126
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7739 - loss: 0.6314
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8424 - loss: 0.4410
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9405 - loss: 0.2340
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9708 - loss: 0.1135

# %%
# -------- Prediction After Training --------
idx2tag = {i: t for t, i in tag2idx.items()}

def ner_predict(sentence):
    words = sentence.split()
    seq = [word2idx.get(w, word2idx["OOV"]) for w in words]
    padded = pad_sequences([seq], maxlen=MAX_LEN, padding="post")
    
    pred = model.predict(padded)
    pred_tags = [idx2tag[np.argmax(p)] for p in pred[0][:len(words)]]
    
    return list(zip(words, pred_tags))

# -------- Test Example --------
test_sentence = ""
result = ner_predict(test_sentence)

print("\nNER Prediction:")
for word, tag in result:
    print(f"{word}: {tag}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# NER Prediction:
# Pranay: B-PERSON
# Shit: B-PERSON
# is: B-PERSON
# very: B-PERSON
# good: B-PERSON
# person: B-PERSON

# %%
with open("models/ner_model.json", "w") as json_file:
    json_file.write(model.to_json())

model.save_weights("models/ner_model_weights.h5")

with open("models/ner_word2idx.pkl", "wb") as f:
    pickle.dump(word2idx, f)

with open("models/ner_tag2idx.pkl", "wb") as f:
    pickle.dump(tag2idx, f)

print("✅ NER Model Trained & Saved")
